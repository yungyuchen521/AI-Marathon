# %% [markdown]
# # [作業1]

# %%
import numpy as np;

# %%
def MSE(y, y_hat):
    return sum( (y - y_hat)**2 ) / len(y);

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 你選的這組資料為何重要
#
# 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 蒐集而來的資料型態為何
#
# 這組資料想解決的問題如何評估

# %% [markdown]
# ### Data Name：TV Shows and Movies listed on Netflix
#
# ##### Kaggle Data Link: https://www.kaggle.com/shivamb/netflix-shows
#
# ### Importance
# We can derive useful insights regrading the industry.
#
# E.g.
#
# Comparing what content is available in different countries.
#
# Identifying similar content by matching text-based features.
#
# Network analysis of Actors / Directors in order to find interesting insights.
#
# Has Netflix been increasingly focusing on TV rather than movies in recent years?
#
#
# ### Data Source
# A third-party search engine of Netflix called Flixable.
#
# ### Data Type
# A csv form.
#
# ### Evaluation
# How the insights derived from "Importance" predict the trend on Netflix.

# %% [markdown]
# # [作業3]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 蒐集而來的資料型態為何
# 你要回答的問題，其如何評估 (tips：你的假設如何驗證)

# %% [markdown]
# ### Problem
# To enhance the overall performance, we start from 2 aspects:
#
# 1. customers satisfaction
# 2. driver demployment efficiency
#
# ### Data & Source
# data1: comments on the service - from app / social media / questionnaire
#
# data2: numbers of passengers in different time / location - from
#
# ### Methods & Expected Insights & Actions
# data1 -> sentimental analysis -> identify room for improvement in the service -> employee training
#
# data2 -> regression -> demands prediction -> more accurate drivers deployment
#
# ### Evaluation
# 1. customer ratings
# 2. idle drivers
