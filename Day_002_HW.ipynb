# %% [markdown]
# ## [作業目標]
# 了解機器學習適合應用的領域與範疇。

# %% [markdown]
# ## [作業重點]
# 透過瞭解機器學習的運作方式，找出非常適用機器學習應用的領域及其原因

# %% [markdown]
# ## 作業
# 請找出一個你認為機器學習可以發光發熱的領域並闡述原因?

# %% [markdown]
# ## Risk Management
#
# Market prediction is vital to companies of all kinds.
#
# Whoever able to forecasts the trends are privileged to seize the opportunities and avoid the risks.
#
# However, the factors involved can be way to overwhelming for human beings.
#
# This is where machine learning comes in handy.
#
# It can handle greater amount of data and consider a more comprehensive set of factors to yield higher accuracy.
